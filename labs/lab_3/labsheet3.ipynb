# %% [markdown]
# # Lab 3: Least Squares Method
#
#
# ## Introduction
# In this lab we will introduce you to the least squares method which is used to reconstruct a line (i.e. find its parameters) from a series of points.
#
# This lab also serves as an introduction to the CW1: Unknown Signal, which will require you to extend the least squares method to non-linear applications.
#
# As always we'll begin by importing the necessary modules for the lab.

# %%
from __future__ import print_function # to avoid issues between Python 2 and 3 printing

import numpy as np
from skimage import data, io, color, transform, exposure
from scipy import stats
import matplotlib.pyplot as plt

# show matplotlib figures inline
# %matplotlib inline

# %%
# By default we set figures to be 6"x4" on a 110 dots per inch (DPI) screen 
# (adjust DPI if you have a high res screen!)
plt.rc('figure', figsize=(6, 4), dpi=110)
plt.rc('font', size=10)

# %% [markdown]
# ## 1.  Get some numbers
#
# We'll begin by generating a series of points from a given equation with noise applied.
#
# Generate a sequence of 10 numbers, using the following equation
#
# $$
# y_i=0.2+0.5x_i+e_i
# $$
#
# where $x_i$ is a *uniformly distributed* random number between 0 and 1 and $e_i$ is a *random* number from $\mathcal{N}(\mu = 0, \sigma^2 = 0.01)$.

# %%
# write your code here
xs = np.random.rand(10, 1)
#print(np.random.normal(0, 0.01, sample.shape))
ys = xs * 0.5 + 0.2 + np.random.normal(0, 0.1, xs.shape)

print(ys)
# Out:
# [[0.18714578]
#  [0.2935134 ]
#  [0.45789453]
#  [0.28063399]
#  [0.39478322]
#  [0.20081662]
#  [0.43232317]
#  [0.71202877]
#  [0.27145313]
#  [0.44476388]]

# %% [markdown]
# Generate a scatter plot of $y_i$ versus $x_i$.

# %%
# write your code here
fig, ax = plt.subplots()
ax.set_xlabel("xs")
ax.set_ylabel("ys")
ax.scatter(xs, ys);

# %% [markdown]
# ## 2. Create a general function
#
# Change the above code to a function that receives the parameters $a$, $b$ and $n$ for the equation $y_i = a + b x_i + e_i$ and returns $n$ samples as shown in the previous exercise.
#
# Use the code to generate 100 samples from the equation above and visualise them.

# %%
# write your code here

def generate_sample(a, b, n):
    x_s = np.random.rand(n, 1)
    y_s = a + x_s * b + np.random.normal(0, 0.1, x_s.shape)
    return np.concatenate((x_s, y_s), axis=1)

sample_100 = generate_sample(0.2, 0.5, 100)
print(sample_100)

fig, ax= plt.subplots()
ax.set_xlabel("xs")
ax.set_ylabel("ys")
ax.scatter(sample_100[:,0], sample_100[:,1]);
# Out:
# [[6.73100508e-02 2.56498070e-01]
#  [8.92537493e-01 4.59203113e-01]
#  [5.97858402e-01 4.67978638e-01]
#  [6.89766893e-01 5.81534023e-01]
#  [8.50235580e-03 2.58165536e-01]
#  [1.54784121e-02 3.10900477e-01]
#  [9.10780491e-01 6.98831980e-01]
#  [2.57241471e-01 3.04907079e-01]
#  [2.28680218e-01 2.34569247e-01]
#  [4.83271481e-01 5.39762671e-01]
#  [9.08460095e-01 6.65973811e-01]
#  [3.64379078e-03 2.57360901e-01]
#  [8.18719633e-01 6.93966611e-01]
#  [6.49417898e-01 5.26764382e-01]
#  [9.41161010e-01 8.31700859e-01]
#  [2.16332706e-01 3.63486320e-01]
#  [5.43326075e-01 4.60072044e-01]
#  [8.30026490e-01 7.72603631e-01]
#  [5.32042727e-01 5.20382191e-01]
#  [2.49659062e-01 2.76950628e-01]
#  [2.33895169e-01 2.30604064e-01]
#  [4.47090505e-01 3.39426074e-01]
#  [7.12604981e-01 6.00979140e-01]
#  [4.14314386e-01 3.71885659e-01]
#  [1.57382579e-01 2.27916745e-01]]

# %% [markdown]
# ## 3. Least squares ##
# Using the sequences ${y_i}$ and ${x_i}$ from **2**, implement the matrix form of the least squares method to determine estimates of the parameters $a$ and $b$ (which we denote as $a'$ and $b'$) assuming that $y_i=a+bx_i$.
#
# **Hints**
# * The formula for the matrix form of least squares is given by: $A=(X^T.X)^{-1}.X^T.Y$ where $A=[a',b']$.
# * It is important that you keep track of the dimensions of your matrices, especially $X$. Remember that $X^T \cdot X$ should give a 2x2 matrix.
# * Because of the equation being in the form of $y_i=a+bx_i$ the first column of X should be all 1s.
# * You don't need to use your code for matrix inverse and can instead use the function `np.linalg.inv`.

# %%
# write your code here

def fit_wh(x_s_s, y_s_s):
    return np.linalg.inv(np.transpose(x_s_s) @ x_s_s) @ np.transpose(x_s_s) @ y_s_s

X = sample_100[:,0]

XSS = np.column_stack((np.ones(X.shape), X))

Y = sample_100[:,1]

mm = fit_wh(XSS, Y)
print(mm)
fig, ax= plt.subplots()
ax.set_xlabel("xs")
ax.set_ylabel("ys")
ax.scatter(sample_100[:,0], sample_100[:,1])

ax.plot(XSS[:,1], XSS@mm, 'r', label="fitted line")
# Out:
# [0.17280747 0.53841143]

# %% [markdown]
# ### Why aren't the values of a and b the same as in the original equation?

# %% [markdown]
# ## 4. Line fitting and plotting
#
# Draw the line defined by the estimated values of $a'$ and $b'$ on top of the scatter plot generated in point **2**.

# %%
# write your code here

# %% [markdown]
# ## 5. Outliers
#
# Add a few outliers to your data. For example, add the points $\{(0.5, 5), (0.6, 5), (0.7, 5)\}$ to the sampled sequences from **2**.
#
# Re-estimate the best line that fits the data after the addition of the outliers.
#
# Plot the best fit line before and after the outlier data, in a way similar to the figure below (including the colouring and the legend).
#
#
# ### Hint
# * Both `plot` and `scatter` have an optional parameter label which allows you to label each series for the legend.
# * Both `plot` and `scatter` have an optional parameter c which can be passed a colour, e.g. `c='r'` will set the colour to red.
# * `ax.legend` will create a legend automatically as long as your series have been labelled.
#
# ![Line fit](lineFit.jpg)

# %%
# write your code here
outliers = np.array([[0.5, 5], [0.6, 5], [0.7, 5]])


sample_outlier = np.concatenate((sample_100, outliers), axis=0)

XO = np.column_stack((np.ones(sample_outlier[:,0].shape), sample_outlier[:,0]))

YO = sample_outlier[:,1]
print(XO)
print(YO)
mmo = fit_wh(XO, YO)
fig, ax= plt.subplots()
ax.set_xlabel("xs")
ax.set_ylabel("ys")
ax.scatter(sample_100[:,0], sample_100[:,1], label='data')

ax.scatter(outliers[:,0], outliers[:,1], marker='x', c='black', label="outliers")

ax.plot(XSS[:,1], XSS@mm, 'r', label="fitted line without outlier")
ax.plot(XO[:,1], XO@mmo, 'g', label="fitted line with outlier")
ax.legend()
# Out:
# [[1.         0.06731005]
#  [1.         0.89253749]
#  [1.         0.5978584 ]
#  [1.         0.68976689]
#  [1.         0.00850236]
#  [1.         0.01547841]
#  [1.         0.91078049]
#  [1.         0.25724147]
#  [1.         0.22868022]
#  [1.         0.48327148]
#  [1.         0.9084601 ]
#  [1.         0.00364379]
#  [1.         0.81871963]
#  [1.         0.6494179 ]
#  [1.         0.94116101]
#  [1.         0.21633271]
#  [1.         0.54332607]
#  [1.         0.83002649]
#  [1.         0.53204273]
#  [1.         0.24965906]
#  [1.         0.23389517]
#  [1.         0.76362144]
#  [1.         0.39589105]
#  [1.         0.17320361]
#  [1.         0.50621211]
#  [1.         0.46946502]
#  [1.         0.03458909]
#  [1.         0.03477535]
#  [1.         0.25284848]
#  [1.         0.06581109]
#  [1.         0.42441012]
#  [1.         0.74776921]
#  [1.         0.77762759]
#  [1.         0.67473613]
#  [1.         0.30778164]
#  [1.         0.23350865]
#  [1.         0.37726934]
#  [1.         0.22606124]
#  [1.         0.55880814]
#  [1.         0.62061984]
#  [1.         0.70541547]
#  [1.         0.23864489]
#  [1.         0.91618128]
#  [1.         0.90267611]
#  [1.         0.69302193]
#  [1.         0.59007003]
#  [1.         0.47157117]
#  [1.         0.1796723 ]
#  [1.         0.85017516]
#  [1.         0.34199727]
#  [1.         0.82447371]
#  [1.         0.74123056]
#  [1.         0.04187603]
#  [1.         0.15455004]
#  [1.         0.91996454]
#  [1.         0.17091304]
#  [1.         0.97445407]
#  [1.         0.06128004]
#  [1.         0.67842185]
#  [1.         0.95797566]
#  [1.         0.19884767]
#  [1.         0.93866315]
#  [1.         0.65116984]
#  [1.         0.25691694]
#  [1.         0.47024434]
#  [1.         0.23774458]
#  [1.         0.62991076]
#  [1.         0.45145736]
#  [1.         0.89744401]
#  [1.         0.91794361]
#  [1.         0.39370353]
#  [1.         0.67206715]
#  [1.         0.45226806]
#  [1.         0.97605174]
#  [1.         0.597374  ]
#  [1.         0.89133677]
#  [1.         0.9046018 ]
#  [1.         0.83979076]
#  [1.         0.24107429]
#  [1.         0.44901712]
#  [1.         0.99897035]
#  [1.         0.93218212]
#  [1.         0.37801657]
#  [1.         0.3492624 ]
#  [1.         0.22288057]
#  [1.         0.53030768]
#  [1.         0.9793425 ]
#  [1.         0.23872321]
#  [1.         0.4400471 ]
#  [1.         0.45100827]
#  [1.         0.84809658]
#  [1.         0.13169818]
#  [1.         0.98791556]
#  [1.         0.93232362]
#  [1.         0.03119171]
#  [1.         0.78860461]
#  [1.         0.4470905 ]
#  [1.         0.71260498]
#  [1.         0.41431439]
#  [1.         0.15738258]
#  [1.         0.5       ]
#  [1.         0.6       ]
#  [1.         0.7       ]]
# [2.56498070e-01 4.59203113e-01 4.67978638e-01 5.81534023e-01
#  2.58165536e-01 3.10900477e-01 6.98831980e-01 3.04907079e-01
#  2.34569247e-01 5.39762671e-01 6.65973811e-01 2.57360901e-01
#  6.93966611e-01 5.26764382e-01 8.31700859e-01 3.63486320e-01
#  4.60072044e-01 7.72603631e-01 5.20382191e-01 2.76950628e-01
#  2.30604064e-01 5.83388802e-01 3.41641427e-01 2.68318438e-01
#  4.02509202e-01 3.61583543e-01 2.35796464e-01 7.33172397e-02
#  3.73073086e-01 2.64574495e-02 4.10084417e-01 5.83194189e-01
#  5.49607173e-01 6.13899804e-01 4.21995522e-01 4.31652302e-01
#  5.19703789e-01 3.37754733e-01 5.06540889e-01 5.31565650e-01
#  3.56562270e-01 3.26416540e-01 5.37908879e-01 7.67827196e-01
#  5.28181771e-01 4.05632151e-01 5.34727460e-01 1.47581660e-01
#  7.20412871e-01 3.55334242e-01 7.64475426e-01 5.24984157e-01
#  1.42487678e-01 1.87690390e-01 5.49638756e-01 4.53416118e-01
#  6.51279664e-01 7.79435056e-04 5.18452153e-01 6.11804967e-01
#  3.18409823e-01 7.07855879e-01 4.81980311e-01 3.29832132e-01
#  4.43648862e-01 2.73835670e-01 5.27313379e-01 5.26175505e-01
#  6.02981863e-01 5.72694908e-01 4.92294232e-01 6.29232041e-01
#  3.83983741e-01 8.23336436e-01 4.61197021e-01 5.51070106e-01
#  7.62947053e-01 5.21232878e-01 3.84301414e-01 2.32164322e-01
#  6.99190178e-01 4.57498811e-01 3.92622066e-01 3.26935205e-01
#  9.34182427e-02 4.74462548e-01 6.31752672e-01 4.29040319e-01
#  4.48580242e-01 3.25860603e-01 6.92433334e-01 1.22736859e-01
#  6.83461232e-01 7.35436493e-01 1.53643548e-01 7.69927674e-01
#  3.39426074e-01 6.00979140e-01 3.71885659e-01 2.27916745e-01
#  5.00000000e+00 5.00000000e+00 5.00000000e+00]

# %% [markdown]
# ## 6. Calculating the error
#
# We can now calculate the error in the predicted line using sum squared error (which is what least squares regression is minimising).
#
# Calculate the error of the best fit line and the best fit line with outliers.
#
# **Hint**
# * The sum squared error formula is $\sum_i (\hat{y}_i - y_i)^2$ where $\hat{y}_i = a + bx_i$.

# %%
# write your code here
YT = XSS @ mm
sewoo = [(Y[i] - YT[i])**2 for i in range(len(YT))]
sewoo = sum(sewoo)
print(sewoo)

YTO = XO @ mmo
sewo = [(YO[i] - YTO[i])**2 for i in range(len(YTO))]
sewo = sum(sewo)
print(sewo)
# Out:
# 0.8370335877416024
# 59.82045585876918

# %% [markdown]
# ## 7. Moving to a non-linear system
#
# So far we have been using the least squares method only to find the line of best fit for linear equations, however it can be extended quite easily to certain non-linear lines.
#
# Adapting this method lies in the creation of the $X$ matrix. The matrix we construct has two columns, the first a column of ones and the second a column of x values. Note how each column represents a function applied to x: $x^0$, $x^1$.
#
# If we were instead given the function $y = a + be^x$ to apply the least squares method we can just modify how we define $X$: instead of the second column including $x^1$ we can insert $e^x$.
#
# Given the set of points below, calculate $a$ and $b$ assuming they fit an exponential curve.
# ### Hint
# * `np.exp(new_x)` will define the new column to add.

# %%
new_x = np.array([-5, -4, -2, -1.5, -0.5, 0.5, 0.75, 1, 1.3, 1.9, 2.1, 2.4, 2.8, 3, 3.2])
new_y = np.array([0.407, 0.42, 0.549, 0.645, 1.07, 2.21, 2.73, 3.39, 4.44, 7.75, 9.38, 12.5, 18.5, 22.5, 27.4])

new_x_mod = np.column_stack((np.ones(new_x.shape), np.exp(new_x)))

new_mh = fit_wh(new_x_mod, new_y)
print(new_mh)
# write your code here
# Out:
# [0.39780844 1.10035113]

# %% [markdown]
# ### Visualising the result
# We can now visualise the fitted line as a figure as before using `plot`. Due to the non-linear nature of the equation we can use `np.linspace(-5, 3.2, 100)` which returns 100 evenly spaced numbers in the interval between -5 and 3.2.
#
# Create a graph plotting both the original points and the fitted line as below:
# ![Exp line fit](exp_line_fit.png)

# %%
# write your code here
fig, ax= plt.subplots()
ax.scatter(new_x, new_y, c="blue")

ax.plot(new_x, new_x_mod@new_mh, c='r')

# %% [markdown]
# ### What other types of functions can we extend this to?
#
# For example why can't we fit to the function $y=a \cdot e^{bx}$?
